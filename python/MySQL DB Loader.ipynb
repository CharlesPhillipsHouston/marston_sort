# %%
#censored. ;)
db_user = None
db_host = None
db_pass = None
db_name = None
data_dir = '/home/ckuethe/ipython/satellite_data/daily-tle-download/'

# %%
import mysql.connector

from zipfile import ZipFile
from bz2 import BZ2File
import json
from dateutil.parser import parse as dateparser
import re
import datetime
from math import pi, degrees

# sgp4
from sgp4.io import twoline2rv, verify_checksum, fix_checksum
from sgp4.earth_gravity import wgs84, wgs72
# OrbitalPy
from orbital.utilities import eccentric_anomaly_from_mean, ConvergenceError

import csv
import arrow
import os
from math import pi

# https://github.com/cbassa/twoline
from twoline import twoline

# %%
catdir = os.path.join(data_dir, 'satcat')
catfile = sorted(os.listdir(catdir))[-1]

satcat = dict()
with BZ2File(os.path.join(catdir, catfile)) as fd:
    tmp = json.load(fd)
    for rec in tmp:
        satcat[rec['INTLDES']] = satcat[str(rec['NORAD_CAT_ID'])] = satcat[int(rec['NORAD_CAT_ID'])] = rec

print(len(satcat))
# Out:
# 136815

# %%
def spacetrack_record_build(line0, line1, line2,
                            query_date=None,
                            classification=None,
                            originator='UNKNOWN',
                            filename='',
                            skip_analyst=True,
                            satcat = {}):
    '''Given a TLE, construct an object that looks like what would be returned by the Space-Track API'''
    #Death to undocumented magic numbers
    F_OBJNUM = 1
    F_INTLDES = 2
    F_EPOCH = 3

    HOURS_PER_DAY = 24.0
    MINUTES_PER_DAY = 1440.0
    SECONDS_PER_DAY = 86400.0

    line1 = str(line1.strip())
    line2 = str(line2.strip())

    cat_num = int(line1[2:7])
    # "Analyst" satellites, possibly with characterized orbits, but no identification
    if skip_analyst and cat_num > 80000:
        return None

    if line0 is None:
        line0 = satcat.get(cat_num, {'OBJECT_NAME':''})['OBJECT_NAME']
    else:
        line0 = str(line0.strip())

    # occasionally I get TLEs with no checksum :(
    if len(line1) != 69 or len(line2) != 69:
        line1 = fix_checksum(line1)
        line2 = fix_checksum(line2)

    # because JSPOC doesn't aways left-justify the launch piece...
    intldes = line1[9:17].replace(' ', '')
    try:
        obj_id = intldes_to_objid(intldes)
    except AttributeError:
        return None
    # because python-sgp4 doesn't do this for me
    try:
        rev = int(line2[64:69])
    except ValueError:
        rev = 0

    if len(line0) == 0:
        # Unknown, make something up.
        line0 = "0 UNKNOWN-{}".format(intldes)

    if type(query_date) is not datetime.datetime:
        query_date = datetime.datetime.now()

    #ep_time = epoch_to_datetime(line1[18:32])

    if classification is None:
        classification = line1[7]
    classification = classification.upper()

    name = re.sub('^0 ', '', str(line0))
    try:
        satellite = twoline2rv(line1, line2, wgs72)
    except ValueError:
        return
    
    _n = satellite.no * MINUTES_PER_DAY / (2.0 * pi)

    if name.startswith('OBJECT '):
        obj_type = 'TBA'
    elif re.search(r' DEB(RIS)?$', name):
        obj_type = 'DEBRIS'
    elif re.search(r' r(/?b)?$', name, re.I):
        obj_type = 'ROCKET BODY'
    else:
        obj_type = 'PAYLOAD'

    try:
        ly = int(obj_id.split('-')[0])
    except ValueError:
        ly = None

    st_rec = {
        'NORAD': satellite.satnum,
        'BSTAR': satellite.bstar,
        #'CLASSIFICATION_TYPE': classification,
        # 'CLASSIFIED': classified,
        'ORIGINATOR': originator,
        'DATAFILE': filename,
        'OBJECT_TYPE': obj_type,
        'OBJECT_ID': obj_id,
        'NAME': name,
        'LAUNCH_YEAR': ly,
        #'INTLDES': intldes,
        #'TLE_LINE0': line0,
        'TLE1': line1,
        'TLE2': line2,
        'ARGP': degrees(satellite.argpo),
        'BSTAR': satellite.bstar,
        'RAAN': degrees(satellite.nodeo),
        'REV_AT_EPOCH': rev,
        'ECCENTRICITY': satellite.ecco,
        'INCLINATION': degrees(satellite.inclo),
        'MEAN_MOTION': _n,
        'MEAN_MOTION_DOT': satellite.ndot,
        'MEAN_MOTION_DDOT': satellite.nddot,
        'MEAN_ANOMALY': degrees(satellite.mo),
        'EPOCH': satellite.epoch, # - datetime.timedelta(microseconds=satellite.epoch.microsecond),
    }
    try:
        st_rec['TRUE_ANOMALY'] = float(eccentric_anomaly_from_mean(satellite.ecco, satellite.mo))
    except ConvergenceError:
        pass

    # from the SpaceTrack FAQ:
    '''
    We added semi-major axis, period, apogee, and perigee to the TLE and TLE_latest
    API classes so that users can filter their queries by these values, download only
    the data they need, and decrease the amount of the site's bandwidth that they use.
    Now, all the orbital elements in the satellite catalog (SATCAT) are available in the
    TLE class. However, the value of the same element (e.g. apogee) may not match exactly. 

    Every TLE already displays a value for the object's mean motion ("n") and eccentricity
    ("e"), so we derive these additional four values using the following calculations:

    period = 1440/n
    Using mu, the standard gravitational parameter for the earth (398600.4418),
    semi-major axis "a" = (mu/(n*2*pi/(24*3600))^2)^(1/3)
    Using semi-major axis "a", eccentricity "e", and the Earth's radius in km,
    apogee = (a * (1 + e))- 6378.135
    perigee = (a * (1 - e))- 6378.135
    '''

    _mu = 398600.4418
    _earth_rad = 6378.135
    _a = (_mu/(_n * 2.0 * pi /SECONDS_PER_DAY) ** 2 ) ** (1.0/3.0)
    st_rec['SEMIMAJOR'] = _a
    st_rec['PERIOD'] = MINUTES_PER_DAY / _n
    st_rec['APOGEE'] = (_a * (1 + satellite.ecco)) - _earth_rad
    st_rec['PERIGEE'] = (_a * (1 - satellite.ecco)) - _earth_rad

    return st_rec

def spacetrack_record_fix(row):
    for k in ['EPHEMERIS_TYPE', 'ELEMENT_SET_NO', 'COMMENT', 'ORDINAL']:
        row.pop(k, '')

    for k in row:
        row[str(k)] = str( row.pop(k, ''))

    for k in ['RA_OF_ASC_NODE', 'ARG_OF_PERICENTER', 'MEAN_MOTION_DOT', 'BSTAR',
              'INCLINATION', 'APOGEE', 'PERIGEE', 'MEAN_MOTION', 'MEAN_ANOMALY',
              'MEAN_MOTION_DDOT', 'PERIOD', 'ECCENTRICITY', 'SEMIMAJOR_AXIS']:
        try:
            row[k] = float(row[k])
        except (ValueError, KeyError):
            pass

    for k in ['OBJECT_NUMBER', 'NORAD_CAT_ID', 'REV_AT_EPOCH', 'EPOCH_MICROSECONDS']:
        try:
            row[k] = int(row[k])
        except (ValueError, KeyError):
            pass
    try:
        row['EPOCH'] = dateparser(row['EPOCH']) + datetime.timedelta(microseconds=row['EPOCH_MICROSECONDS'])
    except:
        pass
    
    return row

def intldes_to_objid(intldes):
    '''Given an International Designator YYLLLPPP build a prettier object id: CCYY-LLLPPP'''
    obj_id = list(re.match('^(\d{2})(\w+)$',intldes).groups())
    obj_id[0] = int(obj_id[0])
    if obj_id[0] < 56:
        obj_id[0] += 2000
    elif obj_id[0] <= 99:
        obj_id[0] += 1900
    obj_id = '{}-{}'.format(*obj_id)
    return obj_id

def load_zipped_tle_file(f, n=0):
    zip_file = ZipFile(f, 'r')
    nlist = zip_file.namelist()
    if len(nlist) > 1 and n == 0:
        warnings.warn("Zip archive contains {} members, processing only the first element".format(len(nlist)))

    inner_filename = nlist[n]
    zip_info = zip_file.getinfo(inner_filename)
    data = zip_file.read(inner_filename).decode()
    d = dateparser('{:04}/{:02}/{:02} {:02}:{:02}:{:02}'.format(*zip_info.date_time))
    tles = tle_buf_parser(data)
    return d, tles

def tle_buf_parser(buf):
    '''take a str representing a file of TLEs and turn it into 3 element tuples representing a satellite'''
    pat = r'''\S.+?[\r\n]{1,2} 1\s .*? [0-9] [\r\n]{1,2} 2\s .*? [0-9] [\r\n]{1,2}'''
    rgx = re.compile(pat,re.I|re.M|re.S|re.X)
    matches = re.findall(rgx, buf)
    matches = list(map(lambda x: x.strip(), matches))
    return matches

# %%
def ins_dict_rec(dbh, table, rec):
    '''using the cursor, insert a record into the database'''
    
    placeholders = ['%({})s'.format(i) for i in rec.keys()]
    sql = 'INSERT IGNORE INTO {} ( {} ) VALUES ( {} )'.format(table, ', '.join(list(rec.keys())), ', '.join(placeholders))
    curs = dbh.cursor()
    try:
        curs.execute(sql, rec)
        dbh.commit()
    except Exception:
        pass
    finally:
        curs.close()

def ins_dictlist_rec(dbh, table, reclist):
    '''using the database handle, insert a record into the database'''
    if reclist is None or reclist == []:
        return
    kz = list(reclist[0].keys())
    placeholders = ['%({})s'.format(i) for i in kz]
    sql = 'INSERT IGNORE INTO {} ( {} ) VALUES ( {} )'.format(table, ', '.join(kz), ', '.join(placeholders))
    curs = dbh.cursor()
    curs.execute("set rocksdb_max_row_locks=2000000;")

    try:
        curs.executemany(sql, reclist)
        dbh.commit()
    except Exception:
        pass
    finally:
        curs.close()

def getloaded(dbh):
    curs = dbh.cursor()
    curs.execute('select distinct(datafile) from tles;')
    loaded = set( [x[0] for x in curs.fetchall()])
    curs.close()
    assert(len(loaded))
    return loaded

# %%
# dbh = mariadb.connect(db_host, db_user, db_pass, db_name)
dbh = mysql.connector.connect(user=db_user, passwd=db_pass, host=db_host, port=3306, database=db_name, autocommit=False)

# %%
create_sql = '''
DROP TABLE IF EXISTS {0};
CREATE TABLE {0} (
    _rowid INT NOT NULL AUTO_INCREMENT PRIMARY KEY,
    -- Identification
    object_id CHAR(11) NOT NULL, -- YYYY-LLLPPP
    norad INT NOT NULL,
    name VARCHAR(69), -- All the other tle lines can be 69 characters, why not this too?
    originator VARCHAR(64), -- where did this TLE come from?
    launch_year YEAR NOT NULL,
    object_type ENUM('PAYLOAD', 'BOOSTER', 'DEBRIS', 'FUEL', 'UNKNOWN'),
    epoch DATETIME(6) NOT NULL, -- TIMESTAMP is unixtime which can't grok really old dates
    datafile VARCHAR(64) DEFAULT NULL,

        -- Keps
        eccentricity DOUBLE NOT NULL,
        inclination DOUBLE NOT NULL,
        semimajor DOUBLE NOT NULL,
        raan DOUBLE NOT NULL,
        argp DOUBLE NOT NULL,
        mean_anomaly DOUBLE NOT NULL,
        true_anomaly DOUBLE NOT NULL,
        bstar DOUBLE NOT NULL,
        mean_motion DOUBLE NOT NULL,
        mean_motion_dot DOUBLE NOT NULL,
        mean_motion_ddot DOUBLE NOT NULL,

        -- Derived Parameters
        rev_at_epoch INT NOT NULL,
        apogee FLOAT NOT NULL,
        perigee FLOAT NOT NULL,
        period FLOAT NOT NULL,

        -- TLE
        tle1 CHAR(70) NOT NULL,
        tle2 CHAR(70) NOT NULL

    );

    CREATE INDEX idx_year on {0}(launch_year);
    CREATE INDEX idx_datafile on {0}(datafile);
    CREATE INDEX idx_epoch on {0}(epoch);
    CREATE INDEX idx_objid on {0}(object_id);
    CREATE INDEX idx_norad on {0}(norad);
    CREATE INDEX idx_name on {0}(name);
    CREATE UNIQUE INDEX idx_dedup on {0}(norad, epoch);

'''

#if True:
curs = dbh.cursor()
resp = curs.execute(create_sql.format('tles'), multi=True)

# curs.close()
# dbh.commit()

# %%
lr = list(resp)

# %%
lr
# Out:
# []

# %%
print(create_sql.format('vimpel'))
# Out:
# DROP TABLE IF EXISTS vimpel;
# CREATE TABLE vimpel (
#     _rowid INT NOT NULL AUTO_INCREMENT PRIMARY KEY,
#     -- Identification
#     object_id CHAR(11) NOT NULL, -- YYYY-LLLPPP
#     norad INT NOT NULL,
#     name VARCHAR(69), -- All the other tle lines can be 69 characters, why not this too?
#     originator VARCHAR(64), -- where did this TLE come from?
#     launch_year YEAR NOT NULL,
#     object_type ENUM('PAYLOAD', 'BOOSTER', 'DEBRIS', 'FUEL', 'UNKNOWN'),
#     epoch DATETIME(6) NOT NULL, -- TIMESTAMP is unixtime which can't grok really old dates
#     datafile VARCHAR(64) DEFAULT NULL,
#
#         -- Keps
#         eccentricity DOUBLE NOT NULL,
#         inclination DOUBLE NOT NULL,
#         semimajor DOUBLE NOT NULL,
#         raan DOUBLE NOT NULL,
#         argp DOUBLE NOT NULL,
#         mean_anomaly DOUBLE NOT NULL,
#         true_anomaly DOUBLE NOT NULL,
#         bstar DOUBLE NOT NULL,
#         mean_motion DOUBLE NOT NULL,
#         mean_motion_dot DOUBLE NOT NULL,
#         mean_motion_ddot DOUBLE NOT NULL,
#
#         -- Derived Parameters
#         rev_at_epoch INT NOT NULL,
#         apogee FLOAT NOT NULL,
#         perigee FLOAT NOT NULL,
#         period FLOAT NOT NULL,
#
#         -- TLE
#         tle1 CHAR(70) NOT NULL,
#         tle2 CHAR(70) NOT NULL
#
#     );
#
#     CREATE INDEX idx_year on vimpel(launch_year);
#     CREATE INDEX idx_datafile on vimpel(datafile);
#     CREATE INDEX idx_epoch on vimpel(epoch);
#     CREATE INDEX idx_objid on vimpel(object_id);
#     CREATE INDEX idx_norad on vimpel(norad);
#     CREATE INDEX idx_name on vimpel(name);
#     CREATE UNIQUE INDEX idx_dedup on vimpel(norad, epoch);

# %%
dfz = !ls -r satellite_data/daily-tle-download/classified/classified_2020*zip
loaded = getloaded(dbh)

for datafile in dfz[:15]:
    shortname = datafile.replace('satellite_data/','').replace('daily-tle-download/','')
    if shortname in loaded:
        continue
    print("load", shortname)
    ftime, tles = load_zipped_tle_file(datafile)
    l = [spacetrack_record_build(*t.split('\r\n'), filename=shortname, skip_analyst=False, originator='seesat') for t in tles]
    l = list(filter(lambda x: x is not None, l))

    ins_dictlist_rec(dbh, 'tles', l)
# Out:
# load classified/classified_20200505071702.zip
# load classified/classified_20200425071701.zip

# %%
dfz = !ls satellite_data/daily-tle-download/supplemental/*2020*txt

orgs = {
    'gps': 'navcen',
    'glonass': 'roscosmos',
    'meteosat': 'eumetsat',
    'iss': 'nasa',
    'ses': 'ses',
    'orbcomm': 'orbcomm',
    'starlink': 'spacex',
    'trusat_all': 'trusat',
    'oneweb': 'oneweb',
    'intelsat': 'intelsat',
}

loaded = getloaded(dbh)


for datafile in dfz:
    shortname = datafile.replace('satellite_data/','').replace('daily-tle-download/','')
    if shortname in loaded:
        continue
    print("load", shortname)

    o = shortname.split('/')[-1]
    o = o.split('-')[0]
    o = orgs[o]
    
    with open(datafile) as fd:
        tles = tle_buf_parser(fd.read())
        l = [spacetrack_record_build(*re.split('[\r\n]+', t, re.S|re.M), filename=shortname, skip_analyst=True, originator=o) for t in tles]
        l = list(filter(lambda x: x is not None, l))
        ins_dictlist_rec(dbh, 'tles', l)
    dbh.commit()
# Out:
# load supplemental/glonass-20200110233908.txt
# load supplemental/glonass-20200113233838.txt
# load supplemental/glonass-20200115234258.txt
# load supplemental/glonass-20200120233856.txt
# load supplemental/glonass-20200122234022.txt
# load supplemental/glonass-20200125234150.txt
# load supplemental/glonass-20200206233856.txt
# load supplemental/glonass-20200209233854.txt
# load supplemental/glonass-20200216234252.txt
# load supplemental/glonass-20200218234348.txt
# load supplemental/glonass-20200223234248.txt
# load supplemental/glonass-20200225234320.txt
# load supplemental/glonass-20200302234346.txt
# load supplemental/glonass-20200307233944.txt
# load supplemental/glonass-20200311004420.txt
# load supplemental/glonass-20200314004442.txt
# load supplemental/glonass-20200320004058.txt
# load supplemental/glonass-20200402004010.txt
# load supplemental/glonass-20200403004006.txt
# load supplemental/glonass-20200408004528.txt
# load supplemental/glonass-20200414004228.txt
# load supplemental/glonass-20200422004638.txt
# load supplemental/glonass-20200427004518.txt
# load supplemental/glonass-20200501004144.txt
# load supplemental/glonass-20200507004444.txt
# load supplemental/gps-20200108233854.txt
# load supplemental/gps-20200127234148.txt
# load supplemental/gps-20200204233842.txt
# load supplemental/gps-20200207233914.txt
# load supplemental/gps-20200216234248.txt
# load supplemental/gps-20200221234156.txt
# load supplemental/gps-20200407003956.txt
# load supplemental/gps-20200411004528.txt
# load supplemental/gps-20200421004612.txt
# load supplemental/gps-20200427004514.txt
# load supplemental/gps-20200501004140.txt
# load supplemental/gps-20200505004536.txt
# load supplemental/intelsat-20200229233655.txt
# load supplemental/intelsat-20200315003800.txt
# load supplemental/intelsat-20200426003735.txt
# load supplemental/iss-20200106073627.txt
# load supplemental/iss-20200109233605.txt
# load supplemental/iss-20200110233559.txt
# load supplemental/iss-20200111233638.txt
# load supplemental/iss-20200112233604.txt
# load supplemental/iss-20200114233716.txt
# load supplemental/iss-20200116233828.txt
# load supplemental/iss-20200118233636.txt
# load supplemental/iss-20200119233635.txt
# load supplemental/iss-20200121233715.txt
# load supplemental/iss-20200123233655.txt
# load supplemental/iss-20200124233744.txt
# load supplemental/iss-20200125233737.txt
# load supplemental/iss-20200126233716.txt
# load supplemental/iss-20200128234006.txt
# load supplemental/iss-20200129233716.txt
# load supplemental/iss-20200130233706.txt
# load supplemental/iss-20200201233726.txt
# load supplemental/iss-20200202233610.txt
# load supplemental/iss-20200204073610.txt
# load supplemental/iss-20200206233608.txt
# load supplemental/iss-20200207233618.txt
# load supplemental/iss-20200208233752.txt
# load supplemental/iss-20200209233610.txt
# load supplemental/iss-20200210233714.txt
# load supplemental/iss-20200216233837.txt
# load supplemental/iss-20200218233857.txt
# load supplemental/iss-20200220233852.txt
# load supplemental/iss-20200222233751.txt
# load supplemental/iss-20200223233834.txt
# load supplemental/iss-20200225233856.txt
# load supplemental/iss-20200227233647.txt
# load supplemental/iss-20200228233619.txt
# load supplemental/iss-20200229233828.txt
# load supplemental/iss-20200301233825.txt
# load supplemental/iss-20200303233838.txt
# load supplemental/iss-20200304234525.txt
# load supplemental/iss-20200305233711.txt
# load supplemental/iss-20200306233642.txt
# load supplemental/iss-20200309003628.txt
# load supplemental/iss-20200311003852.txt
# load supplemental/iss-20200313003422.txt
# load supplemental/iss-20200314003912.txt
# load supplemental/iss-20200315003936.txt
# load supplemental/iss-20200316003835.txt
# load supplemental/iss-20200317003839.txt
# load supplemental/iss-20200319003737.txt
# load supplemental/iss-20200320003719.txt
# load supplemental/iss-20200321004043.txt
# load supplemental/iss-20200322003844.txt
# load supplemental/iss-20200323003813.txt
# load supplemental/iss-20200324003802.txt
# load supplemental/iss-20200326003642.txt
# load supplemental/iss-20200326163723.txt
# load supplemental/iss-20200329003656.txt
# load supplemental/iss-20200330003643.txt
# load supplemental/iss-20200401003644.txt
# load supplemental/iss-20200402003647.txt
# load supplemental/iss-20200405003636.txt
# load supplemental/iss-20200406004041.txt
# load supplemental/iss-20200408003916.txt
# load supplemental/iss-20200410003800.txt
# load supplemental/iss-20200411003905.txt
# load supplemental/iss-20200412003925.txt
# load supplemental/iss-20200413003653.txt
# load supplemental/iss-20200415003653.txt
# load supplemental/iss-20200417003641.txt
# load supplemental/iss-20200418163837.txt
# load supplemental/iss-20200420023128.txt
# load supplemental/iss-20200422004046.txt
# load supplemental/iss-20200424004032.txt
# load supplemental/iss-20200426003913.txt
# load supplemental/iss-20200427003906.txt
# load supplemental/iss-20200429003755.txt
# load supplemental/iss-20200501003708.txt
# load supplemental/iss-20200502003815.txt
# load supplemental/iss-20200503004017.txt
# load supplemental/iss-20200504003931.txt
# load supplemental/iss-20200506004048.txt
# load supplemental/iss-20200508003915.txt
# load supplemental/meteosat-20200102073422.txt
# load supplemental/meteosat-20200104073446.txt
# load supplemental/meteosat-20200108073412.txt
# load supplemental/meteosat-20200108233409.txt
# load supplemental/meteosat-20200109233406.txt
# load supplemental/meteosat-20200110073405.txt
# load supplemental/meteosat-20200111233404.txt
# load supplemental/meteosat-20200112233404.txt
# load supplemental/meteosat-20200114233511.txt
# load supplemental/meteosat-20200115233503.txt
# load supplemental/meteosat-20200116233508.txt
# load supplemental/meteosat-20200117233441.txt
# load supplemental/meteosat-20200118233358.txt
# load supplemental/meteosat-20200119233428.txt
# load supplemental/meteosat-20200121233428.txt
# load supplemental/meteosat-20200122233425.txt
# load supplemental/meteosat-20200123233411.txt
# load supplemental/meteosat-20200124233428.txt
# load supplemental/meteosat-20200125233438.txt
# load supplemental/meteosat-20200126233413.txt
# load supplemental/meteosat-20200128233528.txt
# load supplemental/meteosat-20200129233437.txt
# load supplemental/meteosat-20200130233354.txt
# load supplemental/meteosat-20200131233435.txt
# load supplemental/meteosat-20200201233431.txt
# load supplemental/meteosat-20200202233355.txt
# load supplemental/meteosat-20200204233353.txt
# load supplemental/meteosat-20200205233100.txt
# load supplemental/meteosat-20200206233404.txt
# load supplemental/meteosat-20200207233401.txt
# load supplemental/meteosat-20200208233449.txt
# load supplemental/meteosat-20200209233401.txt
# load supplemental/meteosat-20200216153414.txt
# load supplemental/meteosat-20200216233455.txt
# load supplemental/meteosat-20200218233520.txt
# load supplemental/meteosat-20200219233519.txt
# load supplemental/meteosat-20200220233518.txt
# load supplemental/meteosat-20200221233412.txt
# load supplemental/meteosat-20200222233448.txt
# load supplemental/meteosat-20200223233514.txt
# load supplemental/meteosat-20200224233451.txt
# load supplemental/meteosat-20200226233620.txt
# load supplemental/meteosat-20200227233429.txt
# load supplemental/meteosat-20200228233405.txt
# load supplemental/meteosat-20200229233453.txt
# load supplemental/meteosat-20200301233453.txt
# load supplemental/meteosat-20200303233457.txt
# load supplemental/meteosat-20200304233628.txt
# load supplemental/meteosat-20200305233458.txt
# load supplemental/meteosat-20200306233420.txt
# load supplemental/meteosat-20200307233415.txt
# load supplemental/meteosat-20200309003411.txt
# load supplemental/meteosat-20200311003510.txt
# load supplemental/meteosat-20200312015844.txt
# load supplemental/meteosat-20200313003332.txt
# load supplemental/meteosat-20200314003534.txt
# load supplemental/meteosat-20200315003539.txt
# load supplemental/meteosat-20200316003502.txt
# load supplemental/meteosat-20200318003424.txt
# load supplemental/meteosat-20200319003437.txt
# load supplemental/meteosat-20200320003432.txt
# load supplemental/meteosat-20200321003638.txt
# load supplemental/meteosat-20200322003508.txt
# load supplemental/meteosat-20200323003500.txt
# load supplemental/meteosat-20200325003413.txt
# load supplemental/meteosat-20200326003415.txt
# load supplemental/meteosat-20200326163456.txt
# load supplemental/meteosat-20200328003408.txt
# load supplemental/meteosat-20200329003431.txt
# load supplemental/meteosat-20200330003416.txt
# load supplemental/meteosat-20200331003412.txt
# load supplemental/meteosat-20200402003419.txt
# load supplemental/meteosat-20200403003418.txt
# load supplemental/meteosat-20200404003415.txt
# load supplemental/meteosat-20200405003408.txt
# load supplemental/meteosat-20200406003735.txt
# load supplemental/meteosat-20200407003422.txt
# load supplemental/meteosat-20200409003616.txt
# load supplemental/meteosat-20200410003422.txt
# load supplemental/meteosat-20200411003521.txt
# load supplemental/meteosat-20200412003527.txt
# load supplemental/meteosat-20200413003428.txt
# load supplemental/meteosat-20200414003609.txt
# load supplemental/meteosat-20200423003614.txt
# load supplemental/meteosat-20200424003553.txt
# load supplemental/meteosat-20200425003419.txt
# load supplemental/meteosat-20200426003457.txt
# load supplemental/meteosat-20200427003517.txt
# load supplemental/meteosat-20200429003415.txt
# load supplemental/meteosat-20200430003520.txt
# load supplemental/meteosat-20200501003419.txt
# load supplemental/meteosat-20200502003417.txt
# load supplemental/meteosat-20200503003540.txt
# load supplemental/meteosat-20200504003520.txt
# load supplemental/meteosat-20200505003449.txt
# load supplemental/meteosat-20200507003423.txt
# load supplemental/meteosat-20200508003536.txt
# load supplemental/trusat_all-20200104092421.txt
# load supplemental/trusat_all-20200106085549.txt
# load supplemental/trusat_all-20200108090030.txt
# load supplemental/trusat_all-20200112072002.txt
# load supplemental/trusat_all-20200113072002.txt
# load supplemental/trusat_all-20200123072002.txt
# load supplemental/trusat_all-20200125072003.txt
# load supplemental/trusat_all-20200126072002.txt
# load supplemental/trusat_all-20200127072003.txt
# load supplemental/trusat_all-20200128072004.txt
# load supplemental/trusat_all-20200130072002.txt
# load supplemental/trusat_all-20200202072002.txt
# load supplemental/trusat_all-20200206072003.txt
# load supplemental/trusat_all-20200207072004.txt
# load supplemental/trusat_all-20200227072005.txt
# load supplemental/trusat_all-20200228072005.txt
# load supplemental/trusat_all-20200303072005.txt
# load supplemental/trusat_all-20200306072005.txt
# load supplemental/trusat_all-20200308072006.txt
# load supplemental/trusat_all-20200309072006.txt
# load supplemental/trusat_all-20200321072006.txt
# load supplemental/trusat_all-20200327072008.txt
# load supplemental/trusat_all-20200401072010.txt
# load supplemental/trusat_all-20200403072007.txt
# load supplemental/trusat_all-20200405072007.txt
# load supplemental/trusat_all-20200406072008.txt
# load supplemental/trusat_all-20200408072007.txt
# load supplemental/trusat_all-20200409072009.txt
# load supplemental/trusat_all-20200413072008.txt
# load supplemental/trusat_all-20200426072008.txt
# load supplemental/trusat_all-20200427072008.txt
# load supplemental/trusat_all-20200428072008.txt
# load supplemental/trusat_all-20200430072008.txt
# load supplemental/trusat_all-20200502072008.txt
# load supplemental/trusat_all-20200503072008.txt
# load supplemental/trusat_all-20200504072009.txt
# load supplemental/trusat_all-20200505072009.txt
# load supplemental/trusat_all-20200506072008.txt

# %%
dfz = !ls -r satellite_data/daily-tle-download/spacetrack/spacetrack_2020*bz2
loaded = getloaded(dbh)

for datafile in dfz[:15]:
    shortname = datafile.replace('satellite_data/','').replace('daily-tle-download/','')
    if shortname in loaded:
        continue
    print(shortname)
    with BZ2File(datafile) as bz:
        tles = json.load(bz)
        l = [spacetrack_record_build(t['TLE_LINE0'], t['TLE_LINE1'], t['TLE_LINE2'], filename=shortname, skip_analyst=True, originator='spacetrack') for t in tles]
        l = list(filter(lambda x: x is not None, l))
        ins_dictlist_rec(dbh, 'tles', l)
    dbh.commit()

# %%
dfz = !ls -r satellite_data/daily-tle-download/public/public_2020*zip

loaded = getloaded(dbh)

for datafile in dfz[:15]:
    shortname = datafile.replace('satellite_data/','').replace('daily-tle-download/','')
    if shortname in loaded:
        continue
    ftime, tles = load_zipped_tle_file(datafile)
    print(shortname)

    l = [spacetrack_record_build(*t.split('\r\n'), filename=shortname, skip_analyst=True, originator='18spcs') for t in tles]
    l = list(filter(lambda x: x is not None, l))

    ins_dictlist_rec(dbh, 'tles', l)
    dbh.commit()

# %%
print(str(datetime.datetime.now()))
1/0
# Out:
# 2020-05-09 00:04:31.083852
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-13-b81dd15a7dd6> in <module>
#       1 print(str(datetime.datetime.now()))
# ----> 2 1/0
#
# ZeroDivisionError: division by zero

# %%
if True:
    curs = dbh.cursor()
    curs.execute('optimize table tles;')
    curs.fetchone()
    curs.close()
#    dbh.close()

# %%
dfz = !ls -r satellite_data/historical-tle/tle*bz2
loaded = getloaded(dbh)

for datafile in dfz:
    shortname = datafile.replace('satellite_data/','').replace('historical-tle/','')
    if shortname in loaded:
        continue
    print(shortname)
    with BZ2File(datafile) as bz:
        try:
            tles = json.load(bz)
        except json.JSONDecodeError:
            continue
        l = [spacetrack_record_build(t.get('TLE_LINE0', None), t['TLE_LINE1'], t['TLE_LINE2'], filename=shortname, skip_analyst=True, originator='spacetrack', satcat=satcat) for t in tles]
        l = list(filter(lambda x: x is not None, l))
        try:
            ins_dictlist_rec(dbh, 'tles', l)
        except mysql.connector.DatabaseError:
            pass
    dbh.commit()
# Out:
# tle_2010-01-19.json.bz2
# tle_2010-01-18.json.bz2
# tle_2010-01-17.json.bz2
# tle_2010-01-16.json.bz2
# tle_2010-01-15.json.bz2
# tle_2010-01-14.json.bz2
# tle_2010-01-13.json.bz2
# tle_2010-01-12.json.bz2
# tle_2010-01-11.json.bz2
# tle_2010-01-10.json.bz2
# tle_2010-01-09.json.bz2
# tle_2010-01-08.json.bz2
# tle_2010-01-07.json.bz2
# tle_2010-01-06.json.bz2
# tle_2010-01-05.json.bz2
# tle_2010-01-04.json.bz2
# tle_2010-01-03.json.bz2
# tle_2010-01-02.json.bz2
# tle_2010-01-01.json.bz2
# tle_2009-12-31.json.bz2
# tle_2009-12-30.json.bz2
# tle_2009-12-29.json.bz2
# tle_2009-12-28.json.bz2
# tle_2009-12-27.json.bz2
# tle_2009-12-26.json.bz2
# tle_2009-12-25.json.bz2
# tle_2009-12-24.json.bz2
# tle_2009-12-23.json.bz2
# tle_2009-12-22.json.bz2
# tle_2009-12-21.json.bz2
# tle_2009-12-20.json.bz2
# tle_2009-12-19.json.bz2
# tle_2009-12-18.json.bz2
# tle_2009-12-17.json.bz2
# tle_2004-05-30.json.bz2
# tle_2004-05-29.json.bz2
# tle_2004-05-28.json.bz2
# tle_2004-05-27.json.bz2
# tle_2004-05-26.json.bz2
# tle_2004-05-25.json.bz2
# tle_2004-05-24.json.bz2
# tle_2004-05-23.json.bz2
# tle_2004-05-22.json.bz2
# tle_2004-05-21.json.bz2
# tle_2004-05-20.json.bz2

# %%
dfz = !ls satellite_data/historicTLE_COPY/*tle
loaded = getloaded(dbh)

for datafile in dfz:
    shortname = datafile.replace('satellite_data/','').replace('historicTLE_COPY/','')
    if shortname in loaded:
        continue
    objnum = int(shortname.replace('.tle', ''))
    objname = satcat[objnum]['SATNAME'].strip()
    if objnum % 25 == 0:
        print(shortname, objname)
    with open(datafile) as fd:
        buf = fd.readlines()
        l = []
        try:
            while True:
                l.append( spacetrack_record_build(objname, buf[0], buf[1], filename=shortname, originator='spacetrack'))
                buf.pop(1)
                buf.pop(0)
        except IndexError:
            pass
        try:
            ins_dictlist_rec(dbh, 'tles', l)
        except mysql.connector.DatabaseError:
            pass
    dbh.commit()
# Out:
# 10000.tle OPS 9437 (DSCS 2-7)
# 1000.tle TITAN 3A DEB (TRUSS)
# 10025.tle ATLAS CENTAUR R/B
# 10050.tle COSMOS 838 DEB
# 10075.tle DELTA 1 DEB
# 100.tle DISCOVERER 23
# 10100.tle COSMOS 838 DEB
# 10125.tle COSMOS 838 DEB
# 10150.tle COSMOS 931
# 10175.tle COSMOS 934 DEB
# 10200.tle DELTA 1 DEB
# 10225.tle DELTA 1 DEB
# 10250.tle DELTA 1 DEB
# 10275.tle COSMOS 936 DEB
# 10300.tle SL-4 R/B
# 10325.tle COSMOS 938 DEB
# 10350.tle COSMOS 913 DEB
# 10375.tle COSMOS 956
# 10400.tle COSMOS 952 DEB (ANTENNA)
# 10450.tle COSMOS 839 DEB
# 10475.tle DELTA 1 DEB
# 10500.tle SL-4 DEB
# 10525.tle SL-8 DEB
# 10550.tle COSMOS 969 DEB
# 10575.tle COSMOS 970 DEB
# 10600.tle SL-8 R/B
# 10625.tle DELTA 1 DEB
# 10650.tle DELTA 1 DEB
# 10675.tle N-1 R/B
# 10700.tle SL-4 R/B
# 10725.tle COSMOS 993
# 10750.tle DELTA 1 DEB
# 10775.tle SL-13 DEB
# 10825.tle DELTA 1 DEB
# 10850.tle SL-4 DEB
# 10875.tle DELTA 1 DEB
# 10900.tle SL-8 DEB
# 10925.tle MOLNIYA 1-40
# 10950.tle DELTA 1 R/B(2)
# 10975.tle COMSTAR 3
# 11000.tle SL-4 R/B
# 1100.tle COSMOS 57 DEB
# 11050.tle COSMOS 1041
# 11075.tle SL-6 R/B(2)
# 11100.tle SALYUT 6 DEB
# 11125.tle COSMOS 1049 DEB
# 11150.tle COSMOS 1062
# 11175.tle SL-4 DEB
# 11200.tle COSMOS 880 DEB
# 11225.tle COSMOS 880 DEB
# 11250.tle COSMOS 1071 DEB
# 1125.tle COSMOS 57 DEB
# 11275.tle SL-12 PLAT
# 11300.tle COSMOS 1085
# 11325.tle SL-4 R/B
# 11350.tle SALYUT 6 DEB
# 11375.tle COSMOS 1102 DEB
# 11400.tle SL-4 R/B
# 11425.tle COSMOS 1110
# 11450.tle SL-8 R/B
# 11475.tle SL-6 R/B(1)
# 11500.tle SALYUT 6 DEB
# 1150.tle COSMOS 57 DEB
# 11525.tle COSMOS 1126 DEB
# 11550.tle SL-6 R/B(2)
# 11575.tle COSMOS 1138 DEB
# 11600.tle COSMOS 1143
# 11625.tle COSMOS 1112 DEB
# 11650.tle SL-4 R/B
# 11700.tle COSMOS 1164
# 11750.tle COSMOS 1171
# 11775.tle COSMOS 1174 DEB
# 11825.tle SOYUZ-T 2
# 11850.tle OPS 3123
# 11875.tle COSMOS 1192
# 11900.tle SLV-3 R/B
# 11925.tle SL-4 R/B
# 11950.tle COSMOS 1209
# 11975.tle SALYUT 6 DEB
# 12000.tle DELTA 1 DEB
# 12025.tle COSMOS 1213 DEB
# 12050.tle COSMOS 1219
# 12075.tle COSMOS 1204 DEB
# 12100.tle COSMOS 1227
# 12125.tle DELTA 1 R/B(2)
# 12150.tle SL-8 R/B
# 12175.tle DELTA 1 DEB
# 12225.tle DELTA 1 DEB
# 12250.tle DELTA 1 DEB
# 1225.tle COSMOS 57 DEB
# 12275.tle DELTA 1 DEB
# 12300.tle SL-4 R/B
# 12325.tle COSMOS 1255
# 12350.tle SL-4 DEB
# 12375.tle DELTA 1 DEB
# 12400.tle COSMOS 1264
# 12425.tle COSMOS 1265 DEB
# 12450.tle COSMOS 1268 DEB
# 12475.tle COSMOS 1267 DEB
# 12500.tle COSMOS 1273 DEB
# 1250.tle SECOR 2 (EGRS 2)
# 12525.tle SL-4 DEB
# 12550.tle COSMOS 1249 DEB (ANTENNA
# 12575.tle COSMOS 1277 DEB
# 125.tle THOR ABLESTAR DEB
# 12600.tle COSMOS 1281 DEB
# 12625.tle DYNAMICS EXPLORER 2
# 12650.tle COSMOS 1275 DEB
# 12675.tle COSMOS 1275 DEB
# 12700.tle COSMOS 1275 DEB
# 12725.tle COSMOS 1275 DEB
# 12750.tle COSMOS 1275 DEB
# 1275.tle COSMOS 57 DEB
# 12775.tle COSMOS 1275 DEB
# 12800.tle TITAN 3D R/B
# 12825.tle DELTA 1 DEB
# 12850.tle SL-12 R/B(2)
# 12875.tle COSMOS 1307 DEB
# 12900.tle SL-4 DEB
# 12925.tle COSMOS 1316 DEB
# 12950.tle COSMOS 1275 DEB
# 12975.tle COSMOS 1320
# 13000.tle RADIO 4
# 13025.tle ARIANE 1 R/B
# 13050.tle COSMOS 1334 DEB
# 13075.tle SL-6 R/B(2)
# 13100.tle COSMOS 1342 DEB
# 13125.tle SL-6 R/B(1)
# 13150.tle COSMOS 1355
# 13175.tle COSMOS 1365
# 13200.tle COSMOS 1260 DEB
# 13225.tle COSMOS 1260 DEB
# 13250.tle COSMOS 1335 DEB
# 1325.tle SL-6 PLAT
# 13275.tle SALYUT 7 DEB
# 13300.tle STS 4 (OFT-4)
# 13325.tle COSMOS 1220 DEB
# 13350.tle COSMOS 1220 DEB
# 13375.tle COSMOS 1388
# 13400.tle SL-4 R/B
# 13425.tle SOYUZ-T 7
# 13450.tle SL-4 R/B
# 13475.tle COSMOS 926 DEB
# 13500.tle SL-8 DEB *
# 1350.tle SL-8 DEB
# 13525.tle DELTA 1 DEB
# 13550.tle COSMOS 1404 DEB
# 13575.tle DELTA 1 DEB
# 13600.tle COSMOS 1412
# 13650.tle STS 5
# 13675.tle SL-12 R/B(AUX MOTOR)
# 13700.tle SALYUT 7 DEB
# 13725.tle COSMOS 1424
# 13750.tle COSMOS 1427
# 13775.tle COSMOS 375 DEB
# 13800.tle COSMOS 1275 DEB
# 13825.tle DELTA 1 DEB
# 13850.tle COSMOS 1442
# 13875.tle MOLNIYA 3-20
# 13900.tle SL-12 R/B(2)
# 13925.tle COSMOS 1174 DEB
# 13950.tle SL-8 R/B
# 13975.tle COSMOS 1451
# 14000.tle COSMOS 931 DEB
# 1400.tle SL-8 DEB
# 14025.tle COSMOS 1397 DEB
# 14050.tle GOES 6
# 14075.tle COSMOS 1463
# 14100.tle COSMOS 1467
# 14125.tle ARIANE 1 DEB
# 14150.tle COSMOS 1469 DEB
# 14175.tle COSMOS 1477
# 14200.tle SL-6 R/B(1)
# 14225.tle SLV-3 DEB
# 14250.tle N-2 R/B(1)
# 1425.tle THOR ABLESTAR DEB
# 14275.tle COSMOS 1355 DEB
# 14300.tle SL-4 R/B
# 14325.tle COSMOS 1493 DEB
# 14350.tle COSMOS 1220 DEB
# 14375.tle COSMOS 1498 DEB
# 14400.tle COSMOS 1275 DEB
# 14425.tle COSMOS 1505
# 14450.tle COSMOS 1506
# 14475.tle THORAD DELTA 1 DEB
# 14500.tle THOR ABLESTAR DEB *
# 1450.tle SL-9 DEB
# 14525.tle DELTA 1 DEB
# 14550.tle SL-4 R/B
# 14575.tle COSMOS 1512 DEB
# 14600.tle COSMOS 1405 DEB
# 14625.tle SL-8 R/B
# 14650.tle COSMOS 1405 DEB
# 14700.tle SL-14 R/B
# 14725.tle RADUGA 14
# 14750.tle COSMOS 1494 DEB
# 1475.tle THOR ALTAIR DEB
# 14775.tle COSMOS 1537 DEB
# 14800.tle COSMOS 886 DEB
# 14825.tle MOLNIYA 1-60
# 14850.tle SL-4 R/B
# 14875.tle DELTA 1 DEB
# 14900.tle CZ-3 R/B
# 14925.tle COSMOS 1275 DEB
# 14950.tle SL-3 DEB
# 14975.tle SALYUT 7 DEB
# 15000.tle COSMOS 1561
# 1500.tle THOR ABLESTAR DEB
# 15025.tle COSMOS 1557 DEB
# 15050.tle COSMOS 1568 DEB
# 15075.tle SL-12 R/B(AUX MOTOR)
# 150.tle THOR ABLESTAR DEB
# 15100.tle SL-14 R/B
# 15150.tle COSMOS 1582 DEB
# 15175.tle SALYUT 7 DEB
# 15200.tle IRM 1 (AMPTE)
# 15225.tle SL-12 R/B(AUX MOTOR)
# 15250.tle SALYUT 7 DEB
# 15275.tle SALYUT 7 DEB
# 15300.tle COSMOS 1592 DEB
# 15325.tle SL-4 R/B
# 15350.tle COSMOS 1604
# 15375.tle COSMOS 1501 DEB
# 15400.tle SL-4 DEB
# 15425.tle COSMOS 1501 DEB
# 15475.tle SL-14 R/B
# 15500.tle COSMOS 1623 DEB
# 1550.tle SL-8 DEB
# 15525.tle SALYUT 7 DEB
# 15550.tle THORAD AGENA D DEB
# 15575.tle SL-12 R/B(1)
# 15625.tle SL-8 R/B
# 15650.tle COSMOS 1644 DEB
# 15675.tle COSMOS 1648 DEB
# 15700.tle SL-12 R/B(1)
# 15725.tle COSMOS 1461 DEB
# 15750.tle SL-6 DEB
# 1575.tle SL-8 R/B
# 15775.tle COSMOS 249 DEB
# 15800.tle COSMOS 1461 DEB
# 15825.tle ARABSAT 1B
# 15850.tle CIS UNKNOWN 3 DEB
# 15875.tle GIOTTO
# 15925.tle STS 51F
# 15950.tle SCOUT G-1 DEB
# 15975.tle COSMOS 1672 DEB
# 16000.tle SL-4 R/B
# 1600.tle SL-8 DEB
# 16025.tle COSMOS 1678 DEB
# 16050.tle SALYUT 7 DEB
# 16075.tle SOLWIND DEB
# 16100.tle SALYUT 7 DEB
# 16125.tle SL-6 R/B(2)
# 16150.tle SOLWIND DEB
# 16175.tle SALYUT 7 DEB
# 16200.tle SL-12 R/B(1)
# 16225.tle SL-6 DEB
# 16250.tle RADUGA 17
# 1625.tle THOR AGENA D R/B
# 16275.tle OPTUS A2 (AUSSAT 2)
# 16300.tle SOLWIND DEB
# 16325.tle SOLWIND DEB
# 16350.tle SOLWIND DEB
# 16375.tle COSMOS 1375 DEB
# 16400.tle SL-6 DEB
# 16425.tle SOLWIND DEB
# 16450.tle COSMOS 1717
# 16475.tle SOLWIND DEB
# 16500.tle SL-12 R/B(AUX MOTOR)
# 1650.tle TITAN 3C TRANSTAGE DEB
# 16525.tle SOLWIND DEB
# 16550.tle SOLWIND DEB
# 16575.tle SOLWIND DEB
# 16600.tle N-2 R/B(2)
# 16650.tle BRAZILSAT 2
# 16675.tle COSMOS 1588 DEB
# 16700.tle COSMOS 1740 DEB
# 16725.tle SL-4 R/B
# 16750.tle SALYUT 7 DEB
# 1675.tle TITAN 3C TRANSTAGE DEB
# 16775.tle COSMOS 1461 DEB
# 16800.tle COSMOS 1760
# 16825.tle COSMOS 1736 DEB
# 16850.tle SL-6 R/B(1)
# 16875.tle SL-4 R/B
# 16900.tle COSMOS 1765 DEB
# 16925.tle SL-6 R/B(2)
# 16950.tle USA 19 DEB
# 16975.tle COSMOS 1775 DEB
# 17000.tle DELTA 1 DEB
# 1700.tle TITAN 3C TRANSTAGE DEB
# 17025.tle COSMOS 1275 DEB
# 17050.tle COSMOS 1788
# 17075.tle COSMOS 1789 DEB
# 17100.tle SOLWIND DEB
# 17125.tle SL-12 R/B(2)
# 17150.tle ARIANE 1 DEB
# 17175.tle COSMOS 1765 DEB
# 17200.tle ARIANE 1 DEB
# 17225.tle ARIANE 1 DEB
# 17250.tle COSMOS 1682 DEB
# 1725.tle TITAN 3C TRANSTAGE DEB
# 17275.tle COSMOS 1682 DEB
# 17300.tle SL-4 R/B
# 17325.tle ARIANE 1 DEB
# 17350.tle ARIANE 1 DEB
# 17375.tle ARIANE 1 DEB
# 17400.tle SL-11 R/B
# 17425.tle CZ-3 DEB
# 17450.tle ARIANE 1 DEB
# 17475.tle ARIANE 1 DEB
# 17500.tle COSMOS 1813 DEB
# 1750.tle TITAN 3C TRANSTAGE DEB
# 17525.tle COSMOS 1821
# 17550.tle ARIANE 1 DEB
# 17575.tle ARIANE 1 DEB
# 175.tle THOR ABLESTAR DEB
# 17600.tle ARIANE 1 DEB
# 17625.tle COSMOS 1275 DEB
# 17650.tle THOR ABLESTAR DEB
# 17675.tle ARIANE 1 DEB
# 17700.tle ARIANE 1 DEB
# 17725.tle COSMOS 374 DEB *
# 17750.tle COSMOS 1461 DEB
# 17775.tle SOLWIND DEB
# 17800.tle COSMOS 1375 DEB
# 17825.tle SOLWIND DEB
# 17850.tle SL-4 R/B
# 17875.tle SL-12 R/B(2)
# 17900.tle COSMOS 1813 DEB
# 17925.tle COSMOS 1813 DEB
# 17950.tle ARIANE 1 DEB
# 17975.tle COSMOS 1845
# 18000.tle SL-4 R/B
# 18050.tle COSMOS 1813 DEB
# 18075.tle COSMOS 1813 DEB
# 18100.tle COSMOS 1848 DEB
# 18125.tle COSMOS 1848 DEB
# 18150.tle ARIANE 1 DEB
# 18175.tle ARIANE 1 DEB
# 18200.tle ARIANE 1 DEB
# 18225.tle COSMOS 1870
# 18250.tle SOLWIND DEB
# 1825.tle TITAN 3C TRANSTAGE DEB
# 18275.tle COSMOS 1275 DEB
# 18300.tle ARIANE 1 DEB
# 18325.tle COSMOS 1872 DEB
# 18350.tle OPTUS A3 (AUSSAT 3)
# 18375.tle SL-12 R/B(AUX MOTOR)
# 18400.tle COSMOS 1887 DEB
# 18425.tle SOLWIND DEB
# 18450.tle ARIANE 1 DEB
# 18475.tle DELTA 1 DEB
# 18500.tle SL-8 DEB *
# 1850.tle TITAN 3C TRANSTAGE DEB
# 18525.tle SCOUT G-1 DEB
# 18550.tle SL-16 DEB
# 18575.tle COSMOS 1897
# 18600.tle DELTA 1 DEB
# 18625.tle COSMOS 1899
# 18650.tle SL-8 DEB *
# 18675.tle OPS 4682 DEB
# 18700.tle SL-4 R/B
# 18725.tle COSMOS 1823 DEB
# 18750.tle COSMOS 1823 DEB
# 1875.tle SL-8 DEB
# 18775.tle DELTA 1 DEB
# 18800.tle COSMOS 1823 DEB
# 18825.tle COSMOS 1906 DEB
# 18850.tle COSMOS 1915 DEB
# 18875.tle COSMOS 1921
# 18900.tle COSMOS 1906 DEB
# 18950.tle COSMOS 1906 DEB
# 18975.tle COSMOS 1461 DEB
# 19000.tle DELTA 1 DEB
# 1900.tle TITAN 3C TRANSTAGE DEB
# 19025.tle COSMOS 1275 DEB
# 19050.tle ARIANE 1 DEB
# 19075.tle SL-12 PLAT
# 19100.tle COSMOS 1941 DEB
# 19125.tle SL-16 DEB
# 19150.tle THORAD AGENA D DEB
# 19175.tle SL-14 DEB
# 19200.tle COSMOS 1945 DEB
# 19225.tle SOYUZ-TM 4 ORBIT MODULE
# 19250.tle THORAD AGENA D DEB
# 1925.tle TITAN 3C TRANSTAGE DEB
# 19275.tle SL-14 R/B
# 19300.tle THOR ABLESTAR DEB
# 19325.tle SL-8 R/B
# 19350.tle SOLWIND DEB
# 19375.tle COSMOS 1776 DEB
# 19400.tle SL-12 R/B(2)
# 19425.tle COSMOS 886 DEB *
# 19450.tle SL-14 DEB
# 19475.tle COSMOS 886 DEB
# 19500.tle SL-4 DEB
# 1950.tle SL-7 R/B
# 19525.tle COSMOS 1965 DEB
# 19550.tle IUS R/B(2)
# 19575.tle COSMOS 1973 DEB
# 19600.tle SL-12 R/B(AUX MOTOR)
# 19650.tle SL-16 R/B
# 19675.tle COSMOS 1981 DEB
# 19700.tle MIR DEB
# 19725.tle SL-6 DEB
# 19750.tle COSMOS 1988 (GLONASS)
# 1975.tle TITAN 3C TRANSTAGE DEB
# 19775.tle SL-4 R/B
# 19800.tle COSMOS 2002
# 19825.tle SL-8 DEB
# 19850.tle SL-8 DEB
# 19875.tle COSMOS 2003 DEB
# 19900.tle COSMOS 2007
# 19925.tle SL-4 DEB
# 19950.tle OPS 4682 DEB
# 19975.tle SL-4 DEB
# 20000.tle COSMOS 2021
# 2000.tle SL-3 R/B
# 20025.tle COSMOS 2023 (GLONASS)
# 20050.tle ARIANE 1 DEB
# 20075.tle SL-4 DEB
# 200.tle DISCOVERER 34 DEB
# 20100.tle COSMOS 1275 DEB
# 20125.tle SL-4 R/B
# 20150.tle SL-8 R/B
# 20175.tle RESURS F-4
# 20200.tle COSMOS 970 DEB
# 20225.tle COSMOS 1823 DEB
# 20250.tle RESURS F-5 DEB
# 20275.tle COSMOS 2045 DEB
# 20325.tle SMM DEB
# 20350.tle COSMOS 2052
# 20375.tle COSMOS 1960 DEB
# 20400.tle SL-12 R/B(AUX MOTOR)
# 20425.tle COSMOS 1985 DEB
# 20450.tle DELTA 2 R/B(2) (PAM-D)
# 20475.tle MIR DEB
# 20500.tle SL-12 R/B(1)
# 2050.tle TITAN 3C TRANSTAGE DEB
# 20525.tle COSMOS 2060
# 20550.tle COSMOS 2065
# 20600.tle SL-6 DEB
# 20625.tle SL-16 R/B
# 20650.tle WESTFORD NEEDLES
# 20675.tle COSMOS 2083 DEB
# 20700.tle MIR DEB
# 20725.tle DELTA 2 R/B(1)
# 20750.tle COSMOS 2075 DEB
# 20775.tle SL-8 R/B
# 20800.tle METEOSAT 4 AKM
# 20825.tle SL-4 R/B
# 20850.tle CZ-4 DEB
# 20875.tle ARIANE 44L DEB (SPELDA)
# 20900.tle CZ-4 DEB
# 20925.tle SL-12 PLAT
# 20950.tle SL-6 R/B(1)
# 20975.tle COSMOS 2106 DEB
# 21000.tle COSMOS 2108
# 2100.tle TITAN 3C TRANSTAGE DEB
# 21025.tle SL-12 R/B(AUX MOTOR)
# 21050.tle MIR DEB
# 21075.tle DMSP 5D-2 F10 DEB
# 21100.tle COSMOS 2125
# 21125.tle DMSP 5D-2 F10 DEB
# 21150.tle DELTA 2 R/B
# 21175.tle SL-8 DEB
# 21200.tle SL-6 DEB
# 21225.tle GRO
# 21250.tle SL-8 DEB
# 2125.tle OPS 0340
# 21275.tle DELTA 1 DEB
# 21300.tle COSMOS 2144
# 21325.tle DELTA 1 DEB
# 21350.tle DELTA 1 DEB
# 21375.tle DELTA 1 DEB
# 21400.tle SL-8 DEB
# 21425.tle MIR DEB
# 21450.tle DELTA 1 DEB
# 21475.tle DELTA 1 DEB
# 21500.tle DELTA 1 DEB
# 2150.tle OPS 1527 (OV3-1)
# 21525.tle SL-4 R/B
# 21550.tle DELTA 1 DEB
# 21575.tle OSCAR 22 (UoSAT 5)
# 21600.tle DELTA 1 DEB
# 21625.tle MIR DEB
# 21650.tle MIR DEB
# 21675.tle DELTA 1 DEB
# 21700.tle STS 48
# 21725.tle SL-12 DEB
# 21750.tle SL-8 DEB
# 2175.tle ATLAS AGENA D R/B
# 21800.tle DMSP 5D-2 F11 DEB
# 21825.tle DMSP 5D-2 F11 DEB
# 21850.tle SL-6 R/B(2)
# 21875.tle COSMOS 2180
# 21900.tle SL-6 R/B(2)
# 21925.tle SL-12 R/B(2)
# 21975.tle RESURS F-14 DEB
# 22000.tle STS 50
# 2200.tle OPS 1960
# 22025.tle SL-8 DEB
# 22050.tle DELTA 2 R/B(1) (DUVE)
# 22075.tle CZ-2D DEB
# 22100.tle PION 6
# 22125.tle SL-12 R/B(AUX MOTOR)
# 22150.tle SL-12 DEB
# 22175.tle HELLAS-SAT 1 (DFS 3)
# 22200.tle FOTON 5 DEB
# 22225.tle MIR DEB
# 22250.tle SL-12 R/B(AUX MOTOR)
# 2225.tle SCOUT A DEB
# 22275.tle NAVSTAR 29 (USA 87)
# 22300.tle COSMOS 2229
# 22325.tle SL-6 DEB
# 22350.tle SL-16 DEB
# 22375.tle SL-16 DEB
# 22400.tle SL-16 DEB
# 22425.tle SL-16 DEB
# 22450.tle SL-16 DEB
# 22475.tle SL-16 DEB
# 22500.tle SL-16 DEB
# 2250.tle ATLAS D DEB
# 22525.tle COSMOS 2225 DEB
# 22550.tle SL-16 DEB
# 22575.tle SL-16 DEB
# 225.tle THOR ABLESTAR DEB
# 22600.tle SL-16 DEB
# 22625.tle COBE DEB
# 22650.tle COSMOS 2249
# 22675.tle COSMOS 2251
# 22700.tle NAVSTAR 33 (USA 92)
# 22725.tle ARIANE 44L+ R/B
# 22750.tle COBE DEB
# 2275.tle ATLAS D DEB
# 22775.tle COBE DEB
# 22800.tle STS 51 DEB
# 22825.tle EYESAT A
# 22850.tle ARIANE 44L+ DEB
# 22875.tle COSMOS 2265
# 22900.tle COSMOS 1484 DEB
# 22925.tle SL-12 R/B(AUX MOTOR)
# 22950.tle SL-6 R/B(1)
# 22975.tle PROGRESS-M 21
# 23000.tle COSMOS 2269
# 2300.tle SATURN 1B DEB
# 23025.tle STS 62
# 23050.tle SL-12 R/B(AUX MOTOR)
# 23075.tle COBE DEB
# 23100.tle ASLV-D4 R/B
# 23125.tle STRV 1A
# 23150.tle COSMOS 1484 DEB
# 23175.tle INTELSAT 2 (PAS 2)
# 23200.tle TURKSAT 1B
# 23225.tle COSMOS 2290 DEB
# 23250.tle DMSP 5D-2 F12 DEB
# 2325.tle COSMOS 124
# 23275.tle SL-16 DEB
# 23300.tle DELTA 2 DEB
# 23325.tle SL-12 R/B(AUX MOTOR)
# 23350.tle DELTA 2 R/B(2)
# 23400.tle SL-12 PLAT
# 23450.tle SL-12 PLAT
# 23475.tle ODERACS 2E
# 23500.tle STS 67
# 2350.tle TITAN 2 R/B
# 23525.tle H-2 R/B(1)
# 23550.tle SHAVIT R/B
# 23575.tle SL-19 DEB
# 23600.tle STS 71
# 23625.tle SL-12 R/B(2)
# 23650.tle PEGASUS DEB
# 23675.tle SL-4 R/B
# 23700.tle RESURS F-20 DEB
# 23725.tle ASIASAT 2 PKM
# 23750.tle SL-11 R/B
# 2375.tle WESTFORD NEEDLES
# 23775.tle GORIZONT 31
# 23800.tle SL-12 R/B(AUX MOTOR)
# 23825.tle MIR DEB
# 23850.tle SL-13 DEB
# 23875.tle MIR DEB
# 23900.tle MIR DEB
# 23925.tle MIR DEB
# 23950.tle ARIANE 44L+3 R/B
# 23975.tle PEGASUS DEB
# 24000.tle PEGASUS DEB
# 2400.tle ATLAS AGENA D R/B
# 24025.tle PEGASUS DEB
# 24050.tle PEGASUS DEB
# 24075.tle PEGASUS DEB
# 24100.tle PEGASUS DEB
# 24125.tle PEGASUS DEB
# 24150.tle PEGASUS DEB
# 24175.tle PEGASUS DEB
# 24200.tle PEGASUS DEB
# 24225.tle PEGASUS DEB
# 24250.tle PEGASUS DEB
# 24275.tle SL-6 PLAT
# 24300.tle SL-16 DEB
# 24325.tle PEGASUS DEB
# 24350.tle PEGASUS DEB
# 24375.tle PEGASUS DEB
# 24400.tle PEGASUS DEB
# 24425.tle PEGASUS DEB
# 24450.tle PEGASUS DEB
# 24475.tle PEGASUS DEB
# 24500.tle PEGASUS DEB
# 24525.tle PEGASUS DEB
# 24550.tle PEGASUS DEB
# 24575.tle PEGASUS DEB
# 24600.tle PEGASUS DEB
# 24625.tle PEGASUS DEB
# 24675.tle ATLAS 2A CENTAUR R/B
# 24700.tle ISO DEB
# 24725.tle COSMOS 2337
# 24750.tle ARIANE 44L DEB
# 24775.tle PEGASUS DEB
# 24800.tle COSMOS 2342
# 24825.tle PEGASUS DEB
# 24850.tle PEGASUS DEB
# 24875.tle SL-16 DEB
# 24900.tle SL-12 R/B(AUX MOTOR)
# 24925.tle DUMMY MASS 1
# 24950.tle IRIDIUM 31
# 24975.tle PEGASUS DEB
# 25000.tle TITAN 3C TRANSTAGE DEB
# 2500.tle WESTFORD NEEDLES
# 25025.tle TEAMSAT
# 25050.tle INDOSTAR 1
# 25075.tle PEGASUS DEB
# 250.tle THOR ABLESTAR DEB
# 25100.tle INSPEKTOR
# 25125.tle SL-18 DEB
# 25150.tle ARIANE 42P+ DEB
# 25175.tle COMETS
# 25200.tle SL-14 DEB
# 25225.tle SL-14 DEB
# 25250.tle SL-14 DEB
# 2525.tle OPS 5424
# 25275.tle IRIDIUM 59
# 25300.tle COSMOS 1869 DEB
# 25325.tle CZ-2C DEB
# 25350.tle GLOBALSTAR DEB
# 25375.tle SL-4 DEB
# 25400.tle SL-16 R/B
# 25475.tle ORBCOMM FM 21
# 2550.tle CIS UNKNOWN 2 DEB
# 25525.tle SL-12 R/B(2)
# 25650.tle GLOBALSTAR M041
# 25750.tle PEGASUS DEB
# 2575.tle CIS UNKNOWN 2 DEB
# 25825.tle NIMBUS 2 DEB
# 25850.tle SL-6 R/B(2)
# 25875.tle GLOBALSTAR M028
# 25900.tle SL-12 R/B(2)
# 25.tle DISCOVERER 8
# 26000.tle SL-14 DEB
# 2600.tle SL-3 R/B
# 26025.tle SL-14 DEB
# 26075.tle SL-16 DEB
# 26125.tle CZ-4 DEB
# 26150.tle CZ-4 DEB
# 26175.tle CZ-4 DEB
# 26200.tle CZ-4 DEB
# 26225.tle CZ-4 DEB
# 2625.tle SL-3 R/B
# 26275.tle CZ-4 DEB
# 26300.tle CZ-4 DEB
# 26350.tle CZ-4 DEB
# 26375.tle PEGASUS R/B
# 2650.tle OPS 9323 (IDSCS 10)
# 26525.tle TITAN 3C TRANSTAGE DEB
# 26550.tle DNEPR 1 R/B
# 26650.tle CZ-4 DEB
# 26725.tle BLOCK DM-SL R/B
# 2675.tle DIAMANT DEB
# 26850.tle ARIANE 42P+ DEB
# 26900.tle INTELSAT 902
# 26975.tle COSMOS 1024 DEB
# 27000.tle DELTA 2 DEB (DPAF)
# 2700.tle DELTA 1 DEB
# 27025.tle ARIANE 3 DEB
# 27125.tle PSLV DEB
# 27150.tle PSLV DEB
# 2725.tle SL-7 DEB
# 27375.tle IRIDIUM 95
# 27400.tle ASTRA 3A
# 27450.tle IRIDIUM 97
# 27500.tle ATLAS 5 CENTAUR R/B
# 2750.tle COSMOS 155
# 27525.tle KALPANA 1 (METSAT 1)
# 27575.tle DELTA 1 DEB
# 275.tle THOR ABLESTAR DEB
# 27600.tle MICRO LABSAT
# 27625.tle ARIANE 2 DEB
# 27650.tle ARIANE 2 DEB
# 27725.tle THORAD AGENA D DEB
# 27750.tle SL-16 DEB
# 2775.tle DELTA 1 DEB
# 27775.tle COSMOS 2397
# 27800.tle COSMOS 1285 DEB
# 27825.tle THURAYA 2
# 27950.tle ARIANE 5 DEB (SPELTRA)
# 2800.tle SCOUT B DEB
# 28050.tle PSLV R/B
# 28075.tle CZ-4 DEB
# 28200.tle NIMBUS 2 DEB
# 28225.tle CZ-2C DEB
# 2825.tle THOR AGENA D R/B
# 28275.tle COSMOS 1932 DEB
# 28300.tle DMSP 5D-2 F11 DEB
# 28325.tle DMSP 5D-2 F11 DEB
# 28375.tle AMSAT ECHO
# 2850.tle OPS 3559
# 28575.tle ARIANE 44L DEB
# 28600.tle METEOR 2-7 DEB
# 28650.tle HAMSAT
# 28675.tle SCOUT G-1 DEB
# 28850.tle PSLV DEB
# 28900.tle BLOCK DM-SL R/B
# 28925.tle BREEZE-M R/B
# 28950.tle SL-18 DEB
# 28975.tle METEOR 2-15 DEB
# 29000.tle SCATHA AKM
# 2900.tle DIAMANT DEB
# 29050.tle FORMOSAT 3D
# 29075.tle DMSP 5D-2 F11 DEB
# 29100.tle SL-16 DEB
# 29200.tle METEOR 2-6 DEB
# 2925.tle COSMOS 174
# 29275.tle ARIANE 5 R/B
# 29300.tle METEOR 2-17 DEB
# 29325.tle SL-12 DEB
# 29350.tle BLOCK DM-SL R/B
# 29450.tle SL-12 DEB
# 2950.tle WESTFORD NEEDLES
# 29525.tle DMSP 5D-3 F17 DEB
# 29600.tle DMSP 5D-3 F17 DEB
# 29650.tle BREEZE-M R/B
# 29750.tle FENGYUN 1C DEB
# 2975.tle SL-6 PLAT
# 29775.tle FENGYUN 1C DEB
# 29800.tle FENGYUN 1C DEB
# 29825.tle FENGYUN 1C DEB
# 29850.tle FENGYUN 1C DEB
# 29875.tle FENGYUN 1C DEB
# 29925.tle FENGYUN 1C DEB
# 29950.tle FENGYUN 1C DEB
# 29975.tle FENGYUN 1C DEB
# 30000.tle TITAN 3C TRANSTAGE DEB
# 3000.tle OSO 4
# 30025.tle FENGYUN 1C DEB
# 30050.tle FENGYUN 1C DEB
# 30075.tle FENGYUN 1C DEB
# 300.tle THOR ABLESTAR DEB
# 30125.tle FENGYUN 1C DEB
# 30150.tle FENGYUN 1C DEB
# 30175.tle FENGYUN 1C DEB
# 30200.tle FENGYUN 1C DEB
# 30225.tle FENGYUN 1C DEB
# 30250.tle FENGYUN 1C DEB
# 3025.tle OPS 1587
# 30275.tle FENGYUN 1C DEB
# 30300.tle FENGYUN 1C DEB
# 30325.tle FENGYUN 1C DEB
# 30350.tle FENGYUN 1C DEB
# 30375.tle FENGYUN 1C DEB
# 30400.tle FENGYUN 1C DEB
# 30450.tle FENGYUN 1C DEB
# 30475.tle FENGYUN 1C DEB
# 30500.tle FENGYUN 1C DEB
# 3050.tle TITAN 3C TRANSTAGE DEB
# 30525.tle FENGYUN 1C DEB
# 30550.tle FENGYUN 1C DEB
# 30575.tle FENGYUN 1C DEB
# 30600.tle FENGYUN 1C DEB
# 30625.tle FENGYUN 1C DEB
# 30650.tle FENGYUN 1C DEB
# 30675.tle FENGYUN 1C DEB
# 30700.tle FENGYUN 1C DEB
# 30725.tle FENGYUN 1C DEB
# 30750.tle FENGYUN 1C DEB
# 3075.tle SL-7 R/B
# 30775.tle STPSAT 1
# 30800.tle FENGYUN 1C DEB
# 30850.tle FENGYUN 1C DEB
# 30875.tle FENGYUN 1C DEB
# 30900.tle FENGYUN 1C DEB
# 30925.tle FENGYUN 1C DEB
# 30950.tle FENGYUN 1C DEB
# 30975.tle FENGYUN 1C DEB
# 31000.tle FENGYUN 1C DEB
# 3100.tle COSMOS 200
# 31025.tle FENGYUN 1C DEB
# 31125.tle SAUDICOMSAT 3
# 31150.tle FENGYUN 1C DEB
# 31175.tle FENGYUN 1C DEB
# 31225.tle FENGYUN 1C DEB
# 31250.tle FENGYUN 1C DEB
# 3125.tle THOR ABLESTAR DEB
# 31275.tle FENGYUN 1C DEB
# 31300.tle FENGYUN 1C DEB
# 31325.tle FENGYUN 1C DEB
# 31350.tle FENGYUN 1C DEB
# 31450.tle FENGYUN 1C DEB
# 31475.tle FENGYUN 1C DEB
# 31500.tle FENGYUN 1C DEB
# 3150.tle COSMOS 206
# 31550.tle FENGYUN 1C DEB
# 31625.tle FENGYUN 1C DEB
# 31650.tle FENGYUN 1C DEB
# 31675.tle FENGYUN 1C DEB
# 31725.tle FENGYUN 1C DEB
# 3175.tle WESTFORD NEEDLES
# 31800.tle CHINASAT 6B
# 31825.tle FENGYUN 1C DEB
# 31850.tle FENGYUN 1C DEB
# 3200.tle SATURN 5 DEB
# 32025.tle BREEZE-M DEB
# 32050.tle INSAT 4CR
# 32075.tle CBERS 1 DEB
# 32125.tle FENGYUN 1C DEB
# 32150.tle FENGYUN 1C DEB
# 32175.tle FENGYUN 1C DEB
# 32200.tle FENGYUN 1C DEB
# 32225.tle FENGYUN 1C DEB
# 3225.tle SL-6 R/B(2)
# 32275.tle COSMOS 2433 (GLONASS)
# 32325.tle FENGYUN 1C DEB
# 32350.tle FENGYUN 1C DEB
# 32375.tle BREEZE-M R/B
# 32425.tle FENGYUN 1C DEB
# 32450.tle FENGYUN 1C DEB
# 32475.tle NIMBUS 2 DEB
# 32500.tle WINDS (KIZUNA)
# 3250.tle WESTFORD NEEDLES
# 325.tle THOR ABLESTAR DEB
# 3275.tle SL-3 R/B
# 3300.tle SL-4 R/B
# 3325.tle TITAN 3C TRANSTAGE DEB
# 33275.tle AMC-21
# 33375.tle BREEZE-M R/B
# 33450.tle SL-6 R/B(2)
# 33500.tle H-2A R/B
# 3350.tle SL-3 R/B
# 33600.tle FENGYUN 1C DEB
# 33625.tle FENGYUN 1C DEB
# 33650.tle FENGYUN 1C DEB
# 33675.tle FENGYUN 1C DEB
# 33700.tle FENGYUN 1C DEB
# 33750.tle EUTE 33E
# 3375.tle OPS 5247
# 33775.tle IRIDIUM 33 DEB
# 33825.tle COSMOS 2251 DEB
# 33850.tle IRIDIUM 33 DEB
# 33875.tle IRIDIUM 33 DEB
# 33900.tle COSMOS 2251 DEB
# 33950.tle IRIDIUM 33 DEB
# 33975.tle COSMOS 2251 DEB
# 34000.tle COSMOS 2251 DEB
# 3400.tle TITAN 3C TRANSTAGE DEB
# 34050.tle COSMOS 2251 DEB
# 34075.tle IRIDIUM 33 DEB
# 34150.tle IRIDIUM 33 DEB
# 34225.tle BREEZE-M DEB
# 34250.tle BREEZE-M DEB
# 3425.tle TITAN 3C TRANSTAGE DEB
# 34275.tle COSMOS 2251 DEB
# 34300.tle COSMOS 2251 DEB
# 34325.tle COSMOS 2251 DEB
# 34350.tle IRIDIUM 33 DEB
# 34375.tle IRIDIUM 33 DEB
# 34400.tle COSMOS 2251 DEB
# 34425.tle COSMOS 2251 DEB
# 34525.tle IRIDIUM 33 DEB
# 34550.tle COSMOS 2251 DEB
# 34675.tle COSMOS 2251 DEB
# 34725.tle COSMOS 2251 DEB
# 34750.tle COSMOS 2251 DEB
# 3475.tle TITAN 3C TRANSTAGE DEB
# 34775.tle IRIDIUM 33 DEB
# 34825.tle IRIDIUM 33 DEB
# 34850.tle COSMOS 2251 DEB
# 34875.tle COSMOS 2251 DEB
# 35000.tle COSMOS 2251 DEB
# 35025.tle COSMOS 2251 DEB
# 35050.tle IRIDIUM 33 DEB
# 350.tle THOR ABLESTAR DEB
# 35125.tle FENGYUN 1C DEB
# 35175.tle FENGYUN 1C DEB
# 35200.tle FENGYUN 1C DEB
# 35225.tle FENGYUN 1C DEB
# 3525.tle COSMOS 249 DEB
# 35275.tle CZ-2D DEB
# 35325.tle CZ-4 DEB
# 35350.tle PSLV DEB
# 35375.tle CZ-4 DEB
# 35475.tle COSMOS 2251 DEB
# 35500.tle COSMOS 2453
# 3550.tle COSMOS 252 DEB
# 35525.tle SL-14 DEB
# 35550.tle CZ-3A DEB
# 35575.tle YAOGAN 4 DEB
# 35600.tle COSMOS 2251 DEB
# 35625.tle IRIDIUM 33 DEB
# 35650.tle COSMOS 2251 DEB
# 35675.tle COSMOS 2251 DEB
# 35700.tle COSMOS 2251 DEB
# 3575.tle SL-3 R/B
# 35775.tle COSMOS 2251 DEB
# 35800.tle IRIDIUM 33 DEB
# 35825.tle COSMOS 2251 DEB
# 35850.tle IRIDIUM 33 DEB
# 35875.tle BREEZE-M DEB (TANK)
# 35900.tle COSMOS 2251 DEB
# 35925.tle IRIDIUM 33 DEB
# 35975.tle COSMOS 2251 DEB
# 36000.tle COSMOS 2251 DEB
# 3600.tle COSMOS 252 DEB
# 36025.tle IRIDIUM 33 DEB
# 36050.tle COSMOS 2251 DEB
# 36100.tle DMSP 5D-3 F18 DEB
# 36200.tle FENGYUN 1C DEB
# 36225.tle FENGYUN 1C DEB
# 3625.tle SL-7 R/B
# 36300.tle COSMOS 839 DEB
# 36325.tle METEOR 2-8 DEB
# 36350.tle METEOR 2-8 DEB
# 36375.tle COSMOS 2251 DEB
# 36400.tle COSMOS 2459 (GLONASS)
# 36500.tle BREEZE-M R/B
# 3650.tle SL-6 PLAT
# 36550.tle COSMOS 2251 DEB
# 36600.tle BPA 1/SL-24 R/B
# 36625.tle COSMOS 2251 DEB
# 36675.tle FENGYUN 1C DEB
# 36700.tle FENGYUN 1C DEB
# 3675.tle COSMOS 265
# 36800.tle PSLV R/B
# 36875.tle METEOR 2-7 DEB
# 3700.tle SL-7 DEB
# 37150.tle CHINASAT 6A
# 37200.tle BREEZE-M DEB
# 3725.tle TITAN 3C TRANSTAGE DEB
# 37275.tle COSMOS 2251 DEB
# 37325.tle COSMOS 2251 DEB
# 37400.tle FENGYUN 1C DEB
# 37425.tle FENGYUN 1C DEB
# 37475.tle FENGYUN 1C DEB
# 37500.tle COSMOS 2251 DEB
# 3750.tle SCOUT X-4 DEB
# 37550.tle IRIDIUM 33 DEB
# 37625.tle CZ-4 DEB
# 37650.tle DELTA 1 DEB
# 37750.tle BREEZE-M DEB (TANK)
# 3775.tle COSMOS 269
# 37775.tle ASTRA 1N
# 37850.tle COSMOS 2251 DEB
# 37875.tle YAOGAN 12
# 37900.tle FENGYUN 1C DEB
# 37925.tle FENGYUN 1C DEB
# 37950.tle AMOS 5
# 37975.tle COSMOS 2251 DEB
# 38000.tle COSMOS 2251 DEB
# 3800.tle SL-8 DEB
# 38025.tle IRIDIUM 33 DEB
# 38050.tle CZ-3A R/B
# 38100.tle BREEZE-M DEB (TANK)
# 38125.tle FENGYUN 1C DEB
# 38150.tle FENGYUN 1C DEB
# 38175.tle YAOGAN 11 DEB
# 38225.tle IRIDIUM 33 DEB
# 38250.tle BEIDOU 12
# 3825.tle OV1-19
# 38275.tle METEOR 2-5 DEB
# 38300.tle CZ-2D DEB
# 38325.tle CZ-4C DEB
# 38375.tle OPS 4682 DEB
# 38400.tle OPS 4682 DEB
# 38425.tle OPS 4682 DEB
# 38450.tle OPS 4682 DEB
# 38500.tle FENGYUN 1C DEB
# 3850.tle SL-3 DEB
# 38525.tle TRANSIT 5E-5 DEB
# 38575.tle BREEZE-M DEB
# 38600.tle BREEZE-M DEB
# 38625.tle BREEZE-M DEB
# 38650.tle BREEZE-M DEB
# 38700.tle TITAN 3C TRANSTAGE DEB
# 38725.tle FENGYUN 1C DEB
# 38750.tle BLOCK DM-SL R/B
# 3875.tle COSMOS 249 DEB
# 38775.tle BEIDOU 15
# 38825.tle FENGYUN 1C DEB
# 39000.tle CZ-2C R/B
# 3900.tle COSMOS 252 DEB
# 39075.tle GLOBALSTAR M096
# 39100.tle DELTA 1 DEB
# 39150.tle GAOFEN 1
# 39200.tle PSLV R/B
# 39225.tle CZ-2C DEB
# 39250.tle GONETS M 06
# 3925.tle TITAN 3C TRANSTAGE DEB
# 39300.tle SL-16 DEB
# 39325.tle BREEZE-M DEB
# 39350.tle CZ-3C DEB
# 39375.tle RADUGA 1M-3
# 39425.tle APRIZESAT 8
# 39450.tle SL-24 DEB
# 39500.tle THAICOM 6
# 3950.tle ERS 29 (OV5-5)
# 39550.tle COSMOS 2251 DEB
# 39600.tle CZ-3C DEB
# 39625.tle CZ-2C R/B
# 39675.tle COSMOS 1867 COOLANT
# 39700.tle SL-8 DEB
# 39725.tle SL-16 DEB
# 3975.tle DELTA 1 DEB
# 39800.tle SL-12 DEB
# 39825.tle COSMOS 1823 DEB
# 39850.tle SL-16 DEB
# 39900.tle SL-16 DEB
# 39925.tle PEGASUS DEB
# 39950.tle COSMOS 1275 DEB
# 39975.tle SL-14 DEB
# 40000.tle FENGYUN 2C DEB
# 4000.tle BIOSAT 3
# 40025.tle QB50P1
# 40050.tle SL-18 DEB
# 40075.tle AISSAT 2
# 400.tle DELTA 1 DEB (YO)
# 40200.tle CZ-3C DEB
# 40225.tle COSMOS 2251 DEB
# 4025.tle TITAN 3C TRANSTAGE DEB
# 40275.tle YAOGAN 22
# 40300.tle CHUBUSAT 1
# 40350.tle O3B FM12
# 40375.tle ATLAS 5 CENTAUR R/B
# 40400.tle DMSP 5D-2 F13 DEB
# 40425.tle EUTE 115 WEST B(SATMEX 7
# 40450.tle DMSP 5D-2 F13 DEB
# 40475.tle DMSP 5D-2 F13 DEB
# 40500.tle DMSP 5D-2 F13 DEB
# 4050.tle OPS 3654
# 40525.tle DMSP 5D-2 F13 DEB
# 40575.tle DMSP 5D-2 F13 DEB
# 40600.tle DMSP 5D-2 F13 DEB
# 40650.tle RESURS O1 DEB
# 40675.tle DMSP 5D-2 F13 DEB
# 40750.tle CZ-3B R/B
# 4075.tle SL-3 R/B
# 40775.tle ARIANE 1 DEB
# 40800.tle COSMOS 2251 DEB
# 40825.tle CZ-3C DEB
# 40850.tle CZ-3B DEB
# 40875.tle EUTE 8 WEST B
# 40900.tle NUDT-PHONESAT
# 40925.tle PUJIANG 1 (PJ-1)
# 40950.tle FLOCK 2B 1
# 41000.tle FENGYUN 1C DEB
# 4100.tle DELTA 1 DEB
# 41025.tle OBJECT D
# 41050.tle NOAA 16 DEB
# 41075.tle NOAA 16 DEB
# 41150.tle NOAA 16 DEB
# 41175.tle GALILEO 11 (268)
# 41200.tle NOAA 16 DEB
# 41225.tle NOAA 16 DEB
# 41250.tle NOAA 16 DEB
# 4125.tle SL-4 R/B
# 41275.tle NOAA 16 DEB
# 41300.tle NOAA 16 DEB
# 41325.tle CZ-3C R/B
# 41350.tle NOAA 16 DEB
# 41375.tle NOAA 16 DEB
# 41400.tle NOAA 16 DEB
# 41425.tle NOAA 16 DEB
# 41475.tle CADRE
# 41500.tle NOAA 16 DEB
# 4150.tle COSMOS 305
# 41525.tle NOAA 16 DEB
# 41550.tle GALILEO 13 (26A)
# 41575.tle FLOCK 2EP 9
# 41600.tle SATHYABAMASAT
# 41625.tle AX-1
# 41650.tle SL-12 DEB
# 41675.tle SL-12 DEB
# 41700.tle SL-12 DEB
# 41725.tle TIANTONG-1 1
# 41750.tle ARIANE 5 DEB (SYLDA)
# 4175.tle THORAD AGENA D DEB
# 4200.tle THORAD AGENA D DEB
# 4225.tle APOLLO 12 CM
# 4250.tle SKYNET 1
# 425.tle SL-3 DEB
# 4275.tle SL-8 DEB
# 4300.tle SL-7 R/B
# 4325.tle THORAD AGENA D DEB
# 4350.tle SL-3 R/B
# 4375.tle OPS 2863
# 4400.tle CZ-1 DEB
# 4425.tle COSMOS 350
# 4450.tle THORAD AGENA D DEB
# 4475.tle THORAD AGENA D DEB
# 4500.tle COSMOS 249 DEB
# 4525.tle SL-4 R/B
# 4550.tle THORAD AGENA D DEB
# 4575.tle SL-4 DEB
# 4600.tle SL-4 R/B
# 4625.tle COSMOS 375 DEB
# 4650.tle THORAD AGENA D DEB
# 4675.tle THORAD AGENA D DEB
# 4700.tle COSMOS 376 DEB
# 4725.tle COSMOS 375 DEB
# 4750.tle THORAD AGENA D DEB
# 475.tle THOR ABLESTAR DEB
# 4775.tle THORAD AGENA D DEB
# 4800.tle SL-8 R/B
# 4825.tle COSMOS 374 DEB
# 4850.tle SL-3 R/B
# 4875.tle OPS 7776 DEB
# 4950.tle THORAD AGENA D DEB
# 4975.tle THORAD AGENA D DEB
# 5000.tle THORAD AGENA D DEB
# 500.tle SPUTNIK 22 DEB
# 5025.tle THORAD AGENA D DEB
# 5050.tle COSMOS 400
# 5075.tle COSMOS 374 DEB *
# 50.tle DELTA 1 R/B
# 5100.tle COSMOS 397 DEB
# 5125.tle SL-4 DEB
# 5150.tle THORAD AGENA D DEB
# 5175.tle SL-8 R/B
# 5200.tle COSMOS 397 DEB
# 5225.tle SL-8 DEB
# 5250.tle COSMOS 420 DEB
# 525.tle FTV 1157
# 5275.tle THORAD AGENA D DEB
# 5300.tle SL-8 DEB
# 5325.tle COSMOS 397 DEB
# 5350.tle THORAD AGENA D DEB
# 5375.tle TITAN 3C TRANSTAGE DEB
# 5400.tle OV1-20/OV1-21 DEB
# 5425.tle SL-8 DEB
# 5450.tle SL-12 PLAT
# 5475.tle COSMOS 438
# 5500.tle WESTFORD NEEDLES
# 550.tle THOR ABLESTAR DEB
# 5525.tle COSMOS 374 DEB *
# 5550.tle COSMOS 447
# 5575.tle OPS 7616
# 5600.tle THORAD AGENA D DEB
# 5625.tle COSMOS 459
# 5650.tle SL-11 R/B(1)
# 5675.tle ARIEL 4 (UK-4)
# 5700.tle THORAD AGENA D DEB
# 5725.tle COSMOS 466 DEB
# 5750.tle THORAD AGENA D DEB
# 575.tle DELTA 1 R/B
# 5775.tle INTELSAT 4-F4
# 5800.tle COSMOS 462 DEB
# 5825.tle THORAD AGENA D DEB
# 5850.tle COSMOS 474 DEB
# 5875.tle COSMOS 252 DEB
# 5900.tle THORAD AGENA D DEB
# 5925.tle SL-4 R/B
# 5950.tle SL-6 DEB
# 5975.tle DELTA 1 DEB
# 600.tle RADOSE 112
# 6025.tle COSMOS 488 DEB
# 6050.tle SL-4 R/B
# 6075.tle INTERCOSMOS 7
# 6100.tle SL-7 R/B
# 6125.tle SL-8 R/B
# 6150.tle COSMOS 515
# 6175.tle COSMOS 252 DEB
# 6200.tle COSMOS 519 DEB
# 6225.tle COSMOS 523 DEB
# 6250.tle SCOUT B-1 DEB
# 625.tle DELTA 1 R/B
# 6275.tle OPS 7323 (DMSP 5B F3)
# 6325.tle COSMOS 538 DEB
# 6350.tle COSMOS 546
# 6375.tle SL-8 DEB
# 6400.tle SL-13 DEB
# 6450.tle COSMOS 554 DEB
# 6475.tle COSMOS 554 DEB
# 6500.tle COSMOS 554 DEB
# 650.tle THOR ABLESTAR DEB
# 6525.tle COSMOS 554 DEB
# 6650.tle COSMOS 559 DEB
# 6675.tle COSMOS 564
# 6700.tle SL-8 DEB *
# 6750.tle THORAD AGENA D DEB
# 675.tle ERS 12
# 6775.tle COSMOS 577 DEB
# 6800.tle SCOUT D-1 R/B
# 6825.tle COSMOS 585
# 6850.tle COSMOS 593
# 6875.tle COSMOS 601
# 6900.tle COSMOS 603
# 6925.tle COSMOS 603 DEB
# 6950.tle COSMOS 610
# 6975.tle TITAN 3C R/B(1)
# 7000.tle MOLNIYA 2-8
# 700.tle ATLAS CENTAUR 2 DEB
# 7025.tle DELTA 1 DEB
# 7050.tle DELTA 1 DEB
# 7075.tle DELTA 1 DEB
# 7100.tle COSMOS 629
# 7125.tle DELTA 1 DEB
# 7150.tle DELTA 1 DEB
# 7175.tle DELTA 1 DEB
# 7200.tle DELTA 1 DEB
# 7225.tle COSMOS 636
# 7250.tle WESTAR 1
# 7275.tle SL-3 R/B
# 7300.tle THORAD DELTA 1 R/B(1)
# 7325.tle EXPLORER 52 (HAWKEYE)
# 7350.tle SL-8 R/B
# 7375.tle SCOUT D-1 R/B
# 7400.tle SL-12 R/B(AUX MOTOR)
# 7425.tle SL-4 R/B
# 7450.tle COSMOS 686 DEB
# 7475.tle SL-4 DEB
# 7500.tle INTERCOSMOS 12
# 750.tle ELEKTRON 1 DEB
# 7525.tle COSMOS 692 DEB
# 7550.tle THORAD DELTA 1 R/B(1)
# 7575.tle SL-3 R/B
# 75.tle DELTA 1 DEB
# 7600.tle SL-4 DEB
# 7625.tle COSMOS 706
# 7650.tle DELTA 1 R/B(1)
# 7675.tle COSMOS 710
# 7700.tle SL-4 DEB
# 7725.tle COSMOS 720 DEB
# 7750.tle COSMOS 699 DEB
# 775.tle SCOUT X-3 R/B
# 7775.tle COSMOS 727 DEB
# 7800.tle SL-6 R/B(2)
# 7825.tle COSMOS 736
# 7850.tle DELTA 1 DEB
# 7875.tle DELTA 1 DEB
# 7900.tle COSMOS 742
# 7925.tle COSMOS 743
# 7950.tle SL-12 R/B
# 7975.tle DELTA 1 DEB
# 8000.tle TRANSIT 14 DEB
# 800.tle APOLLO MODEL 1
# 8025.tle SOYUZ 18 DEB
# 8050.tle COSMOS 699 DEB
# 8075.tle PAGEOS 1 DEB
# 8100.tle COSMOS 699 DEB
# 8125.tle DELTA 1 DEB
# 8150.tle SL-4 DEB
# 8175.tle THORAD DELTA 1 DEB
# 8275.tle COSMOS 759
# 8300.tle THORAD DELTA 1 DEB
# 8325.tle COSMOS 770
# 8350.tle SL-4 DEB
# 8375.tle DELTA 1 DEB
# 8400.tle THORAD DELTA 1 DEB
# 8425.tle MOLNIYA 3-3
# 8450.tle COSMOS 782
# 8475.tle SL-8 DEB *
# 8500.tle DELTA 1 DEB
# 850.tle OPS 3802
# 8525.tle SL-6 PLAT
# 8550.tle SL-8 DEB *
# 8575.tle DELTA 1 DEB
# 8600.tle SL-6 R/B(2)
# 8625.tle COSMOS 777 DEB
# 8650.tle COSMOS 777 DEB
# 8675.tle DELTA 1 DEB
# 8700.tle SL-4 R/B
# 8725.tle COSMOS 777 DEB
# 8750.tle TITAN 3C R/B(1)
# 875.tle SCOUT X-4 DEB
# 8775.tle DELTA 1 R/B(1)
# 8800.tle SL-3 R/B
# 8825.tle SL-4 DEB
# 8850.tle COSMOS 817 DEB
# 8875.tle COSMOS 821 DEB
# 8900.tle SL-4 DEB
# 8925.tle SL-4 R/B
# 8950.tle DELTA 1 DEB
# 8975.tle DELTA 1 DEB
# 9000.tle DELTA 1 DEB
# 900.tle CALSPHERE 1
# 9025.tle COSMOS 842
# 9050.tle SL-6 R/B(1)
# 925.tle OPS 3062 DEB
# 9275.tle SALYUT 5 DEB
# 9300.tle DELTA 1 DEB
# 9325.tle DELTA 1 DEB
# 9375.tle COSMOS 848 DEB
# 9400.tle SL-6 PLAT
# 9450.tle COSMOS 857 DEB
# 9475.tle COSMOS 816 DEB
# 9500.tle SL-4 R/B
# 950.tle SL-7 DEB
# 9525.tle SL-4 DEB
# 9550.tle DELTA 1 DEB
# 9575.tle SL-6 R/B(1)
# 9600.tle SL-3 R/B
# 9625.tle SL-8 R/B
# 9650.tle COSMOS 886 DEB
# 9675.tle DELTA 1 DEB
# 9700.tle DELTA 1 DEB
# 9725.tle COSMOS 886 DEB
# 975.tle OPS 7040 DEB
# 9800.tle METEOR 1-10 DEB
# 9825.tle COSMOS 886 DEB
# 9850.tle SL-6 R/B(2)
# 9875.tle COSMOS 896 DEB
# 9900.tle SL-8 DEB
# 9925.tle COSMOS 885 DEB
# 9950.tle DELTA 1 DEB
# 9975.tle DELTA 1 DEB

# %%
def orbital_properties(semimajor_axis, e):
    earth_radius = 6378.135
    mu = 398600.4418
    seconds_per_day = 86400.0
    minutes_per_day = seconds_per_day / 60.0

    apogee = (semimajor_axis * (1 + e)) - earth_radius
    perigee = (semimajor_axis * (1 - e)) - earth_radius
    period = 2.0 * pi * (semimajor_axis**3 / mu) ** 0.5
    mean_motion = seconds_per_day / period

    return (apogee, perigee, period/60.0, mean_motion)

# %%
df = 'vimpel/orbits/orbits.20200420.txt'
fd = open(df)

fz = ['line_num','objnum','firstseen', 'epoch','obs_age','semimajor','inclination','raan','eccentricity','arglat','argp','drag_area','magnitude','time_uncert','pos_uncert']

rd = csv.DictReader(fd,fz)

# %%
q = 'select * from tles where norad <> 25544 order by epoch desc limit 1;'
curs = dbh.cursor(dictionary=True)
curs.execute(q)
l = curs.fetchone()
print(l)
curs.close()

# %%
def vimpel2spacetrack(vrec, df):
    r = {'originator': 'vimpel', 'datafile': df, 'object_type': 'UNKNOWN', 'name': None}
    for f in ['objnum', 'obs_age']:
        r[f] = int(vrec[f])
    for f in ['semimajor', 'inclination', 'raan', 'arglat', 'argp', 'eccentricity', 'magnitude', 'drag_area', 'time_uncert', 'pos_uncert']:
        try:
            r[f] = float(vrec[f])
        except ValueError:
            r[f] = None
    
    r['epoch'] = arrow.get(vrec['epoch'], 'DDMMYYYY HHmmss').datetime
    r['firstseen'] = arrow.get(vrec['firstseen'], 'DDMMYYYY').datetime.date()
    r['anomaly'] = r['arglat'] - r['argp']
    if r['anomaly'] < 0.0:
        r['anomaly'] += 360.0
    
    r['apogee'], r['perigee'], r['period'], r['mean_motion'] = orbital_properties(r['semimajor'], r['eccentricity'])

    ey, ed = twoline.datetime_to_epoch(r['epoch'])
    r['name'], r['tle1'], r['tle2'] = twoline.format_tle(r['objnum'], ey, ed, incl=r['inclination'], node=r['raan'], ecc=r['eccentricity'], argp=r['argp'], m=0.0, n=r['mean_motion'], name='vimpel {}'.format(r['objnum']), desig='{}A'.format(r['objnum']))
    
    for f in ['obs_age', 'arglat']:
        r.pop(f, None)
    return r

# %%
l = []
for r in rd:
    r = dict(r)
    l.append(vimpel2spacetrack(r, df))

# %%
l[0]

# %%
ins_dictlist_rec(dbh, 'vimpel', l)
